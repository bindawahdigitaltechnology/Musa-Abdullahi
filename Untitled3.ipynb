# %% [markdown]
# <a href="https://colab.research.google.com/github/bindawahdigitaltechnology/Musa-Abdullahi/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

# Display the uploaded file(s)
for filename in uploaded.keys():
  print(f'Uploaded file: {filename}')
# Out:
#      <input type="file" id="files-2dd24dfa-5933-4b09-8941-1bac83bd4020" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2dd24dfa-5933-4b09-8941-1bac83bd4020">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Upload the image
uploaded = files.upload()

# Display the uploaded image
for filename in uploaded.keys():
  img = mpimg.imread(filename)
  plt.imshow(img)
  plt.axis('off')  # Turn off axis
  plt.show()
# Out:
#      <input type="file" id="files-8b94cf2e-cd43-471a-ba94-80a9eb147708" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b94cf2e-cd43-471a-ba94-80a9eb147708">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np # Import numpy

# Upload multiple images
uploaded = files.upload()

# Display the uploaded images
num_images = len(uploaded)

if num_images == 0:
  print("No images uploaded.")
else:
  # Create subplots
  fig, axs = plt.subplots(1, num_images, figsize=(5 * num_images, 5))

  # Ensure axs is always an array, even for a single subplot
  if num_images == 1:
      axs = np.array([axs])

  for i, (filename, content) in enumerate(uploaded.items()):
    img = mpimg.imread(filename)
    axs[i].imshow(img)
    axs[i].axis('off')  # Turn off axis
    axs[i].set_title(filename)

  plt.show()
# Out:
#      <input type="file" id="files-7498d3f2-806b-4516-a411-1a8d5dd5a346" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7498d3f2-806b-4516-a411-1a8d5dd5a346">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
